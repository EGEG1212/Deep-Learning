# %% [markdown]
# # Hello everyone

# %% [markdown]
# This is my first attempt to build a CNN from scratch. Untill now I am just doing models from 'from keras.dataset import ...', so I hope it works fine (and works as you see at the end and I am very happy with the results)
#
# I will describe as clearly as possible for you if you're a beginner and for myself because I probably gonna use this notebook as my future guides as well. So I want you to understand clearly what I am doing
#
# At the end of the page I'm gonna put some notes just for justify some stuffs I know that can be written in another way or why I'm importing x library since y library can do the same.
#
# So lets begin ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive/
# Out:
# '101-13_딥러닝 워크북.gsheet'
#  호서빅데이터200831-210228
#  AI-Site-2021.gsheet
# 'Colab Notebooks'
#  dctrain.zip
#  Deep-Learning2021.gsheet
# 'FONT TEST.gslides'
# 'Machine-Learning 99.sckit learn.gsheet'
#  Machine-Learning.gsheet
#  my_preprocessed_training_data
#  my_vocab
#  project2Flask-Web_73p.gslides
# '﻿[단축키숏키치트키]ShotkeyCheatkey▲.gsheet'
#  t_academy
#  T_academy_bert.ipynb

# %%
# !cp drive/My\ Drive/dctrain.zip .

# %%
# !unzip -qq dctrain.zip -d dogs-vs-cats

# %%
# !ls -l dogs-vs-cats/
# Out:
# total 768
# drwxr-xr-x 2 root root 782336 Sep 20  2013 train

# %%
import keras
from keras.preprocessing import image
from glob import glob
import cv2, os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Note that even it is a jupyter notebook file I not: using %matplotlib inline
#
# The reason is just because it is easier to run if I download it as .py
#
# I am using the kaggle's notebook path for the train folder and we don't need the test for this project. We gonna create and train our network for those images and thats all.
#
# I write ROW and COL in uppercase because this is the way I learn and used to write my codes with Keras so it is a way to differentiate things that are more important or belong to Keras parte from the most part of code but in this case, we need these variables to resize our image.

# %%
image = cv2.imread('./dogs-vs-cats/train/cat.0.jpg', cv2.IMREAD_COLOR)
plt.imshow(image);

# %%
path = './dogs-vs-cats/train/'

ROW, COL = 96, 96

# %%
dogs, cats = [], []
y_dogs, y_cats = [], []

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Ok. I am like to separate Cats from Dogs (because they tend to fight each other - just kidding). To be honest I don't think you need to do this but I think it is a better way to understand what I am doing and best if you someday need to use this way for a further projects.
#
# y_dogs and y_cats are my labels.
#
# The code bellow are just a definition and selfexplanatory but lets see
#
# I am getting all 'dog' images. In this case there are just .jpg in this folder so it is unnecessary to write things like 'dog*.jpg' and for each dog image (dog_img) I am creating a variable for save all transformations I am going to do.
#
# Read an image then change its color to gray because there are more variables that differentiate a dog from a cat. Resize this image for an OK size (I've tested it and 50x50px still nice but lets use 96x96px) and then convert it into array. If you don't convert it's ok but to read and proccess images as images itself is slower than to proccess them as arrays

# %%
dog_path = os.path.join(path, 'dog*')
dog_path = os.path.join(path, 'dog*')
    for dog_img in glob(dog_path):
        dog = cv2.imread(dog_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-033bc7952aa3> in <module>()
#       1 dog_path = os.path.join(path, 'dog*')
# ----> 2 dog = cv2.imread(dog_img)
#
# NameError: name 'dog_img' is not defined

# %%
def load_dogs():
    print('Loading all dog images\n')
    dog_path = os.path.join(path, 'dog*')
    for dog_img in glob(dog_path):
        dog = cv2.imread(dog_img)
        dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
        dog = cv2.resize(dog, (ROW, COL))
        dog = image.img_to_array(dog)
        dogs.append(dog)
    print('All dog images loaded')

# %%
def load_cats():
    print('Loading all cat images\n')
    cat_path = os.path.join(path, 'cat*')
    for cat_img in glob(cat_path):
        cat = cv2.imread(cat_img)
        cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
        cat = cv2.resize(cat, (ROW, COL))
        cat = image.img_to_array(cat)
        cats.append(cat)
    print('All cat images loaded')

# %%
load_dogs()
# Out:
# Loading all dog images
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-a2955e1122f5> in <module>()
# ----> 1 load_dogs()
#
# <ipython-input-62-ce63968eb3f5> in load_dogs()
#       6         dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
#       7         dog = cv2.resize(dog, (ROW, COL))
# ----> 8         dog = image.img_to_array(dog)
#       9         dogs.append(dog)
#      10     print('All dog images loaded')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'img_to_array'

# %%
print('#################################')
# Out:
# #################################

# %%
load_cats()
# Out:
# Loading all cat images
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-7f8890c10a84> in <module>()
# ----> 1 load_cats()
#
# <ipython-input-63-3e51eb16c3b0> in load_cats()
#       6         cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
#       7         cat = cv2.resize(cat, (ROW, COL))
# ----> 8         cat = image.img_to_array(cat)
#       9         cats.append(cat)
#      10     print('All cat images loaded')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'img_to_array'

# %%
print('Lenght of our dogs array: {}\nLenght of our cats array: {}'.format(len(dogs),len(cats)))
# Out:
# Lenght of our dogs array: 0
# Lenght of our cats array: 0

# %% [markdown]
# Everything is ok. We need exactly 12,500 for cats and 12,500 for dogs

# %%
classes = ['dog', 'cat']

# %% [markdown]
# Acctually it is another step that you can skip (with propper changes with code bellow) but to make it more clearly I am gonna make it explicity that our classes are 'dog' and 'cat'.
#
# And bellow I am just want to see if our code store everything correctly. You know. Sometimes it is easier to work with arrays but are you sure that those numbers means what you whant to they supposed to mean?

# %%
import random

# %%
plt.figure(figsize=(12,8))

for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img)
    
    plt.axis('off')
    plt.title('Suposed to be a {}'.format(classes[0]))
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-c333d651cced> in <module>()
#       3 for i in range(5):
#       4     plt.subplot(1, 5, i+1)
# ----> 5     img = image.array_to_img(random.choice(dogs))
#       6     plt.imshow(img)
#       7
#
# /usr/lib/python3.6/random.py in choice(self, seq)
#     258             i = self._randbelow(len(seq))
#     259         except ValueError:
# --> 260             raise IndexError('Cannot choose from an empty sequence') from None
#     261         return seq[i]
#     262
#
# IndexError: Cannot choose from an empty sequence

# %%
plt.figure(figsize=(12,8))

for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img)
    
    plt.axis('off')
    plt.title('Suposed to be a {}'.format(classes[1]))
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-ce9e1025f11f> in <module>()
#       3 for i in range(5):
#       4     plt.subplot(1, 5, i+1)
# ----> 5     img = image.array_to_img(random.choice(cats))
#       6     plt.imshow(img)
#       7
#
# /usr/lib/python3.6/random.py in choice(self, seq)
#     258             i = self._randbelow(len(seq))
#     259         except ValueError:
# --> 260             raise IndexError('Cannot choose from an empty sequence') from None
#     261         return seq[i]
#     262
#
# IndexError: Cannot choose from an empty sequence

# %% [markdown]
# Nice. They mean what I want to.
#
# But my computer doesn't understand what dogs and cats are but it knew very well what a 0 and 1 means.
#
# Lets give these labels 1 for dogs and 0 for cats, as Kaggle inform.

# %%
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
print('Len of dogs labels: {}\nLen of cats labels: {}'.format(len(y_dogs), len(y_cats)))
# Out:
# Len of dogs labels: 12500
# Len of cats labels: 12500

# %% [markdown]
# # Almost done for data preprocessing

# %% [markdown]
# What I am going to do is to write an X file for our trainning just like the convetion. Put all my values into one array and them I am going to normalize my X just to fit values between 0 and 1 and for this reason I need to specify that my X is a float type
#
# For my y vales or my labels I am just writing them as one array also because we need to use like this to make what is called: One-hot encoding.

# %%
dogs = np.asarray(dogs).astype('float32')
cats = np.asarray(cats).astype('float32')
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')
dogs /= 255
cats /= 255

# %%
X = np.concatenate((dogs,cats), axis=0)
y = np.concatenate((y_dogs, y_cats), axis=0)

# %% [markdown]
# # Start our CNN model

# %%
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.core import Dense, Flatten, Dropout, Activation
from keras.optimizers import Adam
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from keras.models import save_model, load_model

# %% [markdown]
# Now I am just setting my network from what is called Convolution Neural Network. Those variables are not arbitrary and you can change for and from your necessity but the composition for being a CNN still remmaing:
#
# Convolutional -> Convolutional -> MaxPooling -> Convolutional -> Convolutional -> MaxPooling
#
# As I said those variables are not arbitrary but I am happy with my results. I'm not gonna explain everything. The harder part is over with our data pre processing.
#
# Now I suggest you to learn more about networks because it worth. Even myself still very beginner.
#
# We gonna run this network for 100 epochs and I think it is enought to get a great result.
#
# One more thing. I am changing my y again, passing my labels to a matrice that can be 0 or 1, deppending on what my model learn and for this I said that I have 2 classes getting from the lenght of my classes variable which in my opinion is a great way to inform to your model how manny classes you have.

# %%
IMG_CHANNEL = 1
BATCH_SIZE = 128
N_EPOCH = 100
VERBOSE = 2
VALIDAION_SPLIT = .2
OPTIM = Adam()
N_CLASSES = len(classes)

# %%
y = np_utils.to_categorical(y, N_CLASSES)
print('One-Hot Encoding done')
# Out:
# One-Hot Encoding done

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, IMG_CHANNEL), activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(N_CLASSES, activation='softmax')
])

# %%
print('The model was created by following config:')
model.summary()
# Out:
# The model was created by following config:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 36864)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               18874880
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 18,940,898
# Trainable params: 18,940,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=OPTIM, metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint('model_checkpoint/dogs_vs_cats_redux_checkpoint.h5')

# %% [markdown]
# Everything setted up so ...

# %% [markdown]
# # Lets run our model

# %%
print('#################################')
print('########### RUNNING #############')
model.fit(X, y, batch_size=BATCH_SIZE, epochs=N_EPOCH, validation_split=VALIDAION_SPLIT, verbose=VERBOSE)
# Out:
# #################################
# ########### RUNNING #############
# Train on 20000 samples, validate on 5000 samples
# Epoch 1/100
#  - 34s - loss: 0.6406 - acc: 0.6409 - val_loss: 1.1605 - val_acc: 0.1224
# Epoch 2/100
#  - 29s - loss: 0.5443 - acc: 0.7221 - val_loss: 0.5805 - val_acc: 0.7494
# Epoch 3/100
#  - 29s - loss: 0.4889 - acc: 0.7659 - val_loss: 0.5998 - val_acc: 0.7072
# Epoch 4/100
#  - 29s - loss: 0.4385 - acc: 0.7942 - val_loss: 0.8819 - val_acc: 0.5444
# Epoch 5/100
#  - 29s - loss: 0.3935 - acc: 0.8199 - val_loss: 0.6601 - val_acc: 0.6938
# Epoch 6/100
#  - 29s - loss: 0.3500 - acc: 0.8456 - val_loss: 0.5590 - val_acc: 0.7262
# Epoch 7/100
#  - 29s - loss: 0.3012 - acc: 0.8695 - val_loss: 0.4467 - val_acc: 0.8062
# Epoch 8/100
#  - 29s - loss: 0.2486 - acc: 0.8930 - val_loss: 0.4407 - val_acc: 0.8088
# Epoch 9/100
#  - 29s - loss: 0.2057 - acc: 0.9158 - val_loss: 0.4288 - val_acc: 0.8218
# Epoch 10/100
#  - 29s - loss: 0.1600 - acc: 0.9357 - val_loss: 0.7359 - val_acc: 0.7328
# Epoch 11/100
#  - 29s - loss: 0.1272 - acc: 0.9528 - val_loss: 0.5003 - val_acc: 0.8242
# Epoch 12/100
#  - 29s - loss: 0.1051 - acc: 0.9589 - val_loss: 0.6977 - val_acc: 0.7864
# Epoch 13/100
#  - 29s - loss: 0.0877 - acc: 0.9688 - val_loss: 0.7498 - val_acc: 0.7914
# Epoch 14/100
#  - 29s - loss: 0.0750 - acc: 0.9724 - val_loss: 0.7840 - val_acc: 0.7750
# Epoch 15/100
#  - 29s - loss: 0.0673 - acc: 0.9752 - val_loss: 0.6601 - val_acc: 0.8196
# Epoch 16/100
#  - 29s - loss: 0.0641 - acc: 0.9777 - val_loss: 0.7634 - val_acc: 0.8002
# Epoch 17/100
#  - 29s - loss: 0.0624 - acc: 0.9799 - val_loss: 0.7096 - val_acc: 0.8018
# Epoch 18/100
#  - 29s - loss: 0.0482 - acc: 0.9827 - val_loss: 0.8621 - val_acc: 0.7902
# Epoch 19/100
#  - 29s - loss: 0.0517 - acc: 0.9822 - val_loss: 1.1758 - val_acc: 0.7536
# Epoch 20/100
#  - 29s - loss: 0.0446 - acc: 0.9852 - val_loss: 0.7876 - val_acc: 0.8182
# Epoch 21/100
#  - 29s - loss: 0.0429 - acc: 0.9856 - val_loss: 0.8635 - val_acc: 0.7954
# Epoch 22/100
#  - 29s - loss: 0.0405 - acc: 0.9858 - val_loss: 0.9338 - val_acc: 0.7930
# Epoch 23/100
#  - 29s - loss: 0.0388 - acc: 0.9880 - val_loss: 1.0996 - val_acc: 0.7570
# Epoch 24/100
#  - 29s - loss: 0.0355 - acc: 0.9888 - val_loss: 1.5618 - val_acc: 0.6930
# Epoch 25/100
#  - 29s - loss: 0.0331 - acc: 0.9888 - val_loss: 0.9506 - val_acc: 0.7976
# Epoch 26/100
#  - 29s - loss: 0.0283 - acc: 0.9905 - val_loss: 0.9125 - val_acc: 0.8056
# Epoch 27/100
#  - 29s - loss: 0.0364 - acc: 0.9879 - val_loss: 1.1451 - val_acc: 0.7698
# Epoch 28/100
#  - 29s - loss: 0.0343 - acc: 0.9895 - val_loss: 0.6410 - val_acc: 0.8502
# Epoch 29/100
#  - 29s - loss: 0.0359 - acc: 0.9879 - val_loss: 1.0756 - val_acc: 0.7700
# Epoch 30/100
#  - 29s - loss: 0.0324 - acc: 0.9897 - val_loss: 1.1971 - val_acc: 0.7620
# Epoch 31/100
#  - 29s - loss: 0.0389 - acc: 0.9868 - val_loss: 1.1538 - val_acc: 0.7704
# Epoch 32/100
#  - 29s - loss: 0.0323 - acc: 0.9890 - val_loss: 1.2220 - val_acc: 0.7596
# Epoch 33/100
#  - 29s - loss: 0.0286 - acc: 0.9900 - val_loss: 1.0346 - val_acc: 0.7812
# Epoch 34/100
#  - 29s - loss: 0.0240 - acc: 0.9913 - val_loss: 1.2138 - val_acc: 0.7798
# Epoch 35/100
#  - 29s - loss: 0.0254 - acc: 0.9917 - val_loss: 1.0016 - val_acc: 0.7978
# Epoch 36/100
#  - 29s - loss: 0.0206 - acc: 0.9932 - val_loss: 1.1703 - val_acc: 0.7892
# Epoch 37/100
#  - 29s - loss: 0.0250 - acc: 0.9927 - val_loss: 1.4806 - val_acc: 0.7328
# Epoch 38/100
#  - 29s - loss: 0.0304 - acc: 0.9906 - val_loss: 1.3220 - val_acc: 0.7364
# Epoch 39/100
#  - 29s - loss: 0.0249 - acc: 0.9924 - val_loss: 1.0159 - val_acc: 0.7860
# Epoch 40/100
#  - 29s - loss: 0.0274 - acc: 0.9920 - val_loss: 1.4732 - val_acc: 0.7482
# Epoch 41/100
#  - 29s - loss: 0.0235 - acc: 0.9926 - val_loss: 1.2540 - val_acc: 0.7624
# Epoch 42/100
#  - 29s - loss: 0.0213 - acc: 0.9935 - val_loss: 0.7447 - val_acc: 0.8462
# Epoch 43/100
#  - 29s - loss: 0.0192 - acc: 0.9940 - val_loss: 0.8241 - val_acc: 0.8062
# Epoch 44/100
#  - 29s - loss: 0.0278 - acc: 0.9911 - val_loss: 1.0509 - val_acc: 0.7936
# Epoch 45/100
#  - 29s - loss: 0.0267 - acc: 0.9911 - val_loss: 1.4763 - val_acc: 0.7636
# Epoch 46/100
#  - 29s - loss: 0.0284 - acc: 0.9906 - val_loss: 1.0301 - val_acc: 0.7960
# Epoch 47/100
#  - 29s - loss: 0.0214 - acc: 0.9929 - val_loss: 1.2528 - val_acc: 0.7726
# Epoch 48/100
#  - 29s - loss: 0.0227 - acc: 0.9932 - val_loss: 0.8584 - val_acc: 0.8316
# Epoch 49/100
#  - 29s - loss: 0.0204 - acc: 0.9932 - val_loss: 0.9614 - val_acc: 0.8230
# Epoch 50/100
#  - 29s - loss: 0.0214 - acc: 0.9931 - val_loss: 1.4759 - val_acc: 0.7530
# Epoch 51/100
#  - 29s - loss: 0.0203 - acc: 0.9942 - val_loss: 1.2463 - val_acc: 0.7872
# Epoch 52/100
#  - 29s - loss: 0.0216 - acc: 0.9941 - val_loss: 1.3624 - val_acc: 0.7720
# Epoch 53/100
#  - 29s - loss: 0.0215 - acc: 0.9927 - val_loss: 0.9798 - val_acc: 0.8100
# Epoch 54/100
#  - 29s - loss: 0.0168 - acc: 0.9945 - val_loss: 1.0938 - val_acc: 0.8068
# Epoch 55/100
#  - 29s - loss: 0.0203 - acc: 0.9937 - val_loss: 1.0998 - val_acc: 0.8160
# Epoch 56/100
#  - 29s - loss: 0.0172 - acc: 0.9945 - val_loss: 1.3181 - val_acc: 0.7798
# Epoch 57/100
#  - 29s - loss: 0.0226 - acc: 0.9926 - val_loss: 1.2742 - val_acc: 0.7748
# Epoch 58/100
#  - 29s - loss: 0.0212 - acc: 0.9932 - val_loss: 0.6524 - val_acc: 0.8610
# Epoch 59/100
#  - 29s - loss: 0.0216 - acc: 0.9935 - val_loss: 1.1256 - val_acc: 0.7956
# Epoch 60/100
#  - 29s - loss: 0.0203 - acc: 0.9923 - val_loss: 1.1802 - val_acc: 0.7926
# Epoch 61/100
#  - 29s - loss: 0.0214 - acc: 0.9935 - val_loss: 0.9784 - val_acc: 0.8176
# Epoch 62/100
#  - 29s - loss: 0.0191 - acc: 0.9927 - val_loss: 1.0375 - val_acc: 0.8082
# Epoch 63/100
#  - 29s - loss: 0.0152 - acc: 0.9943 - val_loss: 1.1416 - val_acc: 0.8156
# Epoch 64/100
#  - 29s - loss: 0.0234 - acc: 0.9927 - val_loss: 1.4209 - val_acc: 0.7726
# Epoch 65/100
#  - 29s - loss: 0.0234 - acc: 0.9926 - val_loss: 1.1891 - val_acc: 0.7834
# Epoch 66/100
#  - 29s - loss: 0.0208 - acc: 0.9935 - val_loss: 1.8362 - val_acc: 0.7242
# Epoch 67/100
#  - 29s - loss: 0.0196 - acc: 0.9944 - val_loss: 1.2753 - val_acc: 0.7708
# Epoch 68/100
#  - 29s - loss: 0.0148 - acc: 0.9952 - val_loss: 1.0480 - val_acc: 0.8150
# Epoch 69/100
#  - 29s - loss: 0.0212 - acc: 0.9937 - val_loss: 1.1854 - val_acc: 0.7862
# Epoch 70/100
#  - 29s - loss: 0.0164 - acc: 0.9941 - val_loss: 1.1268 - val_acc: 0.8132
# Epoch 71/100
#  - 29s - loss: 0.0124 - acc: 0.9959 - val_loss: 1.4309 - val_acc: 0.7786
# Epoch 72/100
#  - 29s - loss: 0.0199 - acc: 0.9937 - val_loss: 0.8275 - val_acc: 0.8370
# Epoch 73/100
#  - 29s - loss: 0.0149 - acc: 0.9954 - val_loss: 1.4277 - val_acc: 0.7842
# Epoch 74/100
#  - 29s - loss: 0.0157 - acc: 0.9947 - val_loss: 1.1621 - val_acc: 0.7922
# Epoch 75/100
#  - 29s - loss: 0.0184 - acc: 0.9940 - val_loss: 1.0129 - val_acc: 0.8058
# Epoch 76/100
#  - 29s - loss: 0.0231 - acc: 0.9931 - val_loss: 1.0975 - val_acc: 0.8132
# Epoch 77/100
#  - 29s - loss: 0.0178 - acc: 0.9937 - val_loss: 1.0981 - val_acc: 0.8024
# Epoch 78/100
#  - 29s - loss: 0.0177 - acc: 0.9950 - val_loss: 1.1357 - val_acc: 0.8112
# Epoch 79/100
#  - 29s - loss: 0.0158 - acc: 0.9949 - val_loss: 1.0600 - val_acc: 0.8202
# Epoch 80/100
#  - 29s - loss: 0.0159 - acc: 0.9956 - val_loss: 1.6523 - val_acc: 0.7560
# Epoch 81/100
#  - 29s - loss: 0.0167 - acc: 0.9944 - val_loss: 1.2118 - val_acc: 0.8090
# Epoch 82/100
#  - 29s - loss: 0.0155 - acc: 0.9951 - val_loss: 1.4956 - val_acc: 0.7722
# Epoch 83/100
#  - 29s - loss: 0.0170 - acc: 0.9951 - val_loss: 1.1711 - val_acc: 0.8114
# Epoch 84/100
#  - 29s - loss: 0.0150 - acc: 0.9955 - val_loss: 0.8032 - val_acc: 0.8522
# Epoch 85/100
#  - 29s - loss: 0.0152 - acc: 0.9951 - val_loss: 1.4184 - val_acc: 0.7952
# Epoch 86/100
#  - 29s - loss: 0.0198 - acc: 0.9940 - val_loss: 1.7175 - val_acc: 0.7224
# Epoch 87/100
#  - 29s - loss: 0.0130 - acc: 0.9955 - val_loss: 1.5110 - val_acc: 0.7716
# Epoch 88/100
#  - 29s - loss: 0.0128 - acc: 0.9955 - val_loss: 1.2786 - val_acc: 0.7722
# Epoch 89/100
#  - 29s - loss: 0.0159 - acc: 0.9950 - val_loss: 1.3805 - val_acc: 0.7710
# Epoch 90/100
#  - 29s - loss: 0.0179 - acc: 0.9940 - val_loss: 0.8722 - val_acc: 0.8438
# Epoch 91/100
#  - 29s - loss: 0.0162 - acc: 0.9945 - val_loss: 1.5129 - val_acc: 0.7666
# Epoch 92/100
#  - 29s - loss: 0.0136 - acc: 0.9952 - val_loss: 1.8320 - val_acc: 0.7144
# Epoch 93/100
#  - 29s - loss: 0.0135 - acc: 0.9959 - val_loss: 1.3185 - val_acc: 0.7954
# Epoch 94/100
#  - 29s - loss: 0.0185 - acc: 0.9937 - val_loss: 1.1483 - val_acc: 0.8068
# Epoch 95/100
#  - 29s - loss: 0.0139 - acc: 0.9952 - val_loss: 1.3123 - val_acc: 0.7954
# Epoch 96/100
#  - 29s - loss: 0.0115 - acc: 0.9963 - val_loss: 1.0056 - val_acc: 0.8462
# Epoch 97/100
#  - 29s - loss: 0.0158 - acc: 0.9950 - val_loss: 1.3312 - val_acc: 0.7860
# Epoch 98/100
#  - 29s - loss: 0.0236 - acc: 0.9932 - val_loss: 1.2838 - val_acc: 0.7938
# Epoch 99/100
#  - 29s - loss: 0.0139 - acc: 0.9960 - val_loss: 1.3170 - val_acc: 0.7712
# Epoch 100/100
#  - 29s - loss: 0.0101 - acc: 0.9970 - val_loss: 1.0105 - val_acc: 0.8290

# %%
print('########### SCORES ##############')
scores = model.evaluate(X, y, verbose=2)
print('MODEL ACCURACY\n{}: {}'.format(model.metrics_names[1], scores[1]*100))
# Out:
# ########### SCORES ##############
# MODEL ACCURACY
# acc: 96.576

# %% [markdown]
# In terms of building a CNN everything was done by what I learn by watching DeepLizard videos and read in Deep Learning with Keras by Antonio Gulli, Sujit Pal
#
# To pre processing my data I want to give a special thanks to sentdex and RMOTR.
#
# This file is kind different from my .py because I take some advantage of Kaggles kernel and run it for 100 epochs in my .py I was using my GTX 1050 so I just run for 40 epochs because I don't think it is really necessary to run up to this and because it put so much stress for a notebook :P
#
# But in case you run with only 40 epochs the result was "acc: 95.38799999999999%". Pretty close to 100 epochs.
#
# Well. That is it. I hope you enjoy this model.

# %% [markdown]
# # Cifar-10 이미지 분류

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import os
import numpy as np

# %%
# seed 값 설정
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# 나중에 지정될 변수의 값을 미리 세팅
BATCH_SIZE = 32
NUM_CLASSES = 10
EPOCHS = 100
DATA_AUGMENTATION = True
NUM_PREDICTIONS = 20
SAVE_DIR = os.path.join(os.getcwd(), 'model')
MODEL_NAME = 'keras_cifar10_trained_model.h5'

# %%
# The data, split between train and test sets:
(x_train, y_train0), (x_test, y_test0) = cifar10.load_data() #원핫인코딩하기전
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
y_test0[0]#원핫인코딩하기전 array([3], dtype=uint8)
# Out:
# array([3], dtype=uint8)

# %% [markdown]
# ### 데이터확인

# %%
#title 기본 제목 텍스트
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

plt.subplot(141)
plt.imshow(x_train[0], interpolation="bicubic")
plt.subplot(142)
plt.imshow(x_train[4], interpolation="bicubic")
plt.subplot(143)
plt.imshow(x_train[8], interpolation="bicubic")
plt.subplot(144)
plt.imshow(x_train[12], interpolation="bicubic")
plt.grid(False)
plt.show()

# %%
y_train0[0]
# Out:
# array([6], dtype=uint8)

# %%
#@자료형을 실수로 변환한 후 정규화
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
#@원핫인코딩 Convert class vectors to binary class matrices.
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train0, NUM_CLASSES)#y_train0을 10개
y_test = to_categorical(y_test0, NUM_CLASSES)
y_train.shape, y_test.shape
#((50000, 10), (10000, 10))
# Out:
# ((50000, 10), (10000, 10))

# %% [markdown]
# ## 모델 정의/설정/학습

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), #필터=마스크=커널 갯수32
                 padding='same',
                 input_shape=x_train.shape[1:], #(50000, 32, 32, 3)에서 shape[1:]은 뒤에 3개만 ㅋ.ㅋ
                 activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(NUM_CLASSES, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
# initiate RMSprop optimizer
opt = tf.keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)

# %%
# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
modelpath = "model/cifar10-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', 
                                        patience=10)

# %%
history = model.fit(x_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_split=0.2,
                    shuffle=True,
                    callbacks=[early_stopping_callback, checkpointer])#verbose옵션안줌
# Out:
# Epoch 1/100
# 1250/1250 [==============================] - 9s 5ms/step - loss: 2.0571 - accuracy: 0.2351 - val_loss: 1.6271 - val_accuracy: 0.4196
#
# Epoch 00001: val_loss improved from inf to 1.62713, saving model to model/cifar10-cnn-01-1.6271.hdf5
# Epoch 2/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.6167 - accuracy: 0.4077 - val_loss: 1.4882 - val_accuracy: 0.4602
#
# Epoch 00002: val_loss improved from 1.62713 to 1.48821, saving model to model/cifar10-cnn-02-1.4882.hdf5
# Epoch 3/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4568 - accuracy: 0.4694 - val_loss: 1.3721 - val_accuracy: 0.5176
#
# Epoch 00003: val_loss improved from 1.48821 to 1.37206, saving model to model/cifar10-cnn-03-1.3721.hdf5
# Epoch 4/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3626 - accuracy: 0.5094 - val_loss: 1.2412 - val_accuracy: 0.5684
#
# Epoch 00004: val_loss improved from 1.37206 to 1.24115, saving model to model/cifar10-cnn-04-1.2412.hdf5
# Epoch 5/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2914 - accuracy: 0.5396 - val_loss: 1.2693 - val_accuracy: 0.5547
#
# Epoch 00005: val_loss did not improve from 1.24115
# Epoch 6/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2212 - accuracy: 0.5690 - val_loss: 1.1465 - val_accuracy: 0.5995
#
# Epoch 00006: val_loss improved from 1.24115 to 1.14651, saving model to model/cifar10-cnn-06-1.1465.hdf5
# Epoch 7/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1516 - accuracy: 0.5933 - val_loss: 1.0648 - val_accuracy: 0.6275
#
# Epoch 00007: val_loss improved from 1.14651 to 1.06484, saving model to model/cifar10-cnn-07-1.0648.hdf5
# Epoch 8/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1127 - accuracy: 0.6086 - val_loss: 1.0265 - val_accuracy: 0.6426
#
# Epoch 00008: val_loss improved from 1.06484 to 1.02652, saving model to model/cifar10-cnn-08-1.0265.hdf5
# Epoch 9/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0638 - accuracy: 0.6289 - val_loss: 1.0107 - val_accuracy: 0.6492
#
# Epoch 00009: val_loss improved from 1.02652 to 1.01069, saving model to model/cifar10-cnn-09-1.0107.hdf5
# Epoch 10/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0260 - accuracy: 0.6429 - val_loss: 0.9354 - val_accuracy: 0.6780
#
# Epoch 00010: val_loss improved from 1.01069 to 0.93536, saving model to model/cifar10-cnn-10-0.9354.hdf5
# Epoch 11/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9803 - accuracy: 0.6565 - val_loss: 0.9318 - val_accuracy: 0.6717
#
# Epoch 00011: val_loss improved from 0.93536 to 0.93177, saving model to model/cifar10-cnn-11-0.9318.hdf5
# Epoch 12/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9530 - accuracy: 0.6661 - val_loss: 0.8950 - val_accuracy: 0.6924
#
# Epoch 00012: val_loss improved from 0.93177 to 0.89502, saving model to model/cifar10-cnn-12-0.8950.hdf5
# Epoch 13/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9350 - accuracy: 0.6728 - val_loss: 0.8931 - val_accuracy: 0.6923
#
# Epoch 00013: val_loss improved from 0.89502 to 0.89306, saving model to model/cifar10-cnn-13-0.8931.hdf5
# Epoch 14/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9070 - accuracy: 0.6858 - val_loss: 0.8875 - val_accuracy: 0.6900
#
# Epoch 00014: val_loss improved from 0.89306 to 0.88747, saving model to model/cifar10-cnn-14-0.8875.hdf5
# Epoch 15/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8800 - accuracy: 0.6957 - val_loss: 0.8519 - val_accuracy: 0.7022
#
# Epoch 00015: val_loss improved from 0.88747 to 0.85185, saving model to model/cifar10-cnn-15-0.8519.hdf5
# Epoch 16/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8606 - accuracy: 0.7027 - val_loss: 0.8170 - val_accuracy: 0.7184
#
# Epoch 00016: val_loss improved from 0.85185 to 0.81700, saving model to model/cifar10-cnn-16-0.8170.hdf5
# Epoch 17/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8339 - accuracy: 0.7125 - val_loss: 0.7994 - val_accuracy: 0.7234
#
# Epoch 00017: val_loss improved from 0.81700 to 0.79944, saving model to model/cifar10-cnn-17-0.7994.hdf5
# Epoch 18/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8092 - accuracy: 0.7167 - val_loss: 0.7977 - val_accuracy: 0.7238
#
# Epoch 00018: val_loss improved from 0.79944 to 0.79774, saving model to model/cifar10-cnn-18-0.7977.hdf5
# Epoch 19/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8110 - accuracy: 0.7191 - val_loss: 0.7861 - val_accuracy: 0.7284
#
# Epoch 00019: val_loss improved from 0.79774 to 0.78613, saving model to model/cifar10-cnn-19-0.7861.hdf5
# Epoch 20/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7786 - accuracy: 0.7305 - val_loss: 0.7637 - val_accuracy: 0.7387
#
# Epoch 00020: val_loss improved from 0.78613 to 0.76371, saving model to model/cifar10-cnn-20-0.7637.hdf5
# Epoch 21/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7787 - accuracy: 0.7337 - val_loss: 0.7824 - val_accuracy: 0.7292
#
# Epoch 00021: val_loss did not improve from 0.76371
# Epoch 22/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7681 - accuracy: 0.7348 - val_loss: 0.7375 - val_accuracy: 0.7461
#
# Epoch 00022: val_loss improved from 0.76371 to 0.73748, saving model to model/cifar10-cnn-22-0.7375.hdf5
# Epoch 23/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7494 - accuracy: 0.7397 - val_loss: 0.7432 - val_accuracy: 0.7438
#
# Epoch 00023: val_loss did not improve from 0.73748
# Epoch 24/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7436 - accuracy: 0.7415 - val_loss: 0.7325 - val_accuracy: 0.7506
#
# Epoch 00024: val_loss improved from 0.73748 to 0.73247, saving model to model/cifar10-cnn-24-0.7325.hdf5
# Epoch 25/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7287 - accuracy: 0.7513 - val_loss: 0.7289 - val_accuracy: 0.7511
#
# Epoch 00025: val_loss improved from 0.73247 to 0.72892, saving model to model/cifar10-cnn-25-0.7289.hdf5
# Epoch 26/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7174 - accuracy: 0.7520 - val_loss: 0.7269 - val_accuracy: 0.7551
#
# Epoch 00026: val_loss improved from 0.72892 to 0.72694, saving model to model/cifar10-cnn-26-0.7269.hdf5
# Epoch 27/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7240 - accuracy: 0.7530 - val_loss: 0.7061 - val_accuracy: 0.7598
#
# Epoch 00027: val_loss improved from 0.72694 to 0.70608, saving model to model/cifar10-cnn-27-0.7061.hdf5
# Epoch 28/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7084 - accuracy: 0.7561 - val_loss: 0.7122 - val_accuracy: 0.7584
#
# Epoch 00028: val_loss did not improve from 0.70608
# Epoch 29/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7033 - accuracy: 0.7582 - val_loss: 0.6919 - val_accuracy: 0.7647
#
# Epoch 00029: val_loss improved from 0.70608 to 0.69191, saving model to model/cifar10-cnn-29-0.6919.hdf5
# Epoch 30/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6950 - accuracy: 0.7638 - val_loss: 0.7279 - val_accuracy: 0.7559
#
# Epoch 00030: val_loss did not improve from 0.69191
# Epoch 31/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6963 - accuracy: 0.7650 - val_loss: 0.7037 - val_accuracy: 0.7610
#
# Epoch 00031: val_loss did not improve from 0.69191
# Epoch 32/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6828 - accuracy: 0.7657 - val_loss: 0.7263 - val_accuracy: 0.7608
#
# Epoch 00032: val_loss did not improve from 0.69191
# Epoch 33/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6837 - accuracy: 0.7691 - val_loss: 0.7283 - val_accuracy: 0.7545
#
# Epoch 00033: val_loss did not improve from 0.69191
# Epoch 34/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6808 - accuracy: 0.7699 - val_loss: 0.6919 - val_accuracy: 0.7704
#
# Epoch 00034: val_loss improved from 0.69191 to 0.69187, saving model to model/cifar10-cnn-34-0.6919.hdf5
# Epoch 35/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6790 - accuracy: 0.7687 - val_loss: 0.6765 - val_accuracy: 0.7746
#
# Epoch 00035: val_loss improved from 0.69187 to 0.67654, saving model to model/cifar10-cnn-35-0.6765.hdf5
# Epoch 36/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6638 - accuracy: 0.7762 - val_loss: 0.6870 - val_accuracy: 0.7738
#
# Epoch 00036: val_loss did not improve from 0.67654
# Epoch 37/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6614 - accuracy: 0.7732 - val_loss: 0.7080 - val_accuracy: 0.7628
#
# Epoch 00037: val_loss did not improve from 0.67654
# Epoch 38/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6741 - accuracy: 0.7710 - val_loss: 0.6874 - val_accuracy: 0.7685
#
# Epoch 00038: val_loss did not improve from 0.67654
# Epoch 39/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6566 - accuracy: 0.7812 - val_loss: 0.6788 - val_accuracy: 0.7740
#
# Epoch 00039: val_loss did not improve from 0.67654
# Epoch 40/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6571 - accuracy: 0.7756 - val_loss: 0.6868 - val_accuracy: 0.7738
#
# Epoch 00040: val_loss did not improve from 0.67654
# Epoch 41/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6661 - accuracy: 0.7745 - val_loss: 0.6818 - val_accuracy: 0.7719
#
# Epoch 00041: val_loss did not improve from 0.67654
# Epoch 42/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6605 - accuracy: 0.7783 - val_loss: 0.6998 - val_accuracy: 0.7639
#
# Epoch 00042: val_loss did not improve from 0.67654
# Epoch 43/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6525 - accuracy: 0.7807 - val_loss: 0.6560 - val_accuracy: 0.7808
#
# Epoch 00043: val_loss improved from 0.67654 to 0.65599, saving model to model/cifar10-cnn-43-0.6560.hdf5
# Epoch 44/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6565 - accuracy: 0.7772 - val_loss: 0.7278 - val_accuracy: 0.7595
#
# Epoch 00044: val_loss did not improve from 0.65599
# Epoch 45/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6511 - accuracy: 0.7808 - val_loss: 0.6850 - val_accuracy: 0.7717
#
# Epoch 00045: val_loss did not improve from 0.65599
# Epoch 46/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6407 - accuracy: 0.7834 - val_loss: 0.7006 - val_accuracy: 0.7671
#
# Epoch 00046: val_loss did not improve from 0.65599
# Epoch 47/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6453 - accuracy: 0.7807 - val_loss: 0.6737 - val_accuracy: 0.7718
#
# Epoch 00047: val_loss did not improve from 0.65599
# Epoch 48/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6398 - accuracy: 0.7837 - val_loss: 0.6502 - val_accuracy: 0.7790
#
# Epoch 00048: val_loss improved from 0.65599 to 0.65023, saving model to model/cifar10-cnn-48-0.6502.hdf5
# Epoch 49/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6349 - accuracy: 0.7887 - val_loss: 0.6623 - val_accuracy: 0.7796
#
# Epoch 00049: val_loss did not improve from 0.65023
# Epoch 50/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6429 - accuracy: 0.7887 - val_loss: 0.6502 - val_accuracy: 0.7802
#
# Epoch 00050: val_loss did not improve from 0.65023
# Epoch 51/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6352 - accuracy: 0.7862 - val_loss: 0.6704 - val_accuracy: 0.7788
#
# Epoch 00051: val_loss did not improve from 0.65023
# Epoch 52/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6300 - accuracy: 0.7927 - val_loss: 0.6870 - val_accuracy: 0.7728
#
# Epoch 00052: val_loss did not improve from 0.65023
# Epoch 53/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6193 - accuracy: 0.7917 - val_loss: 0.6794 - val_accuracy: 0.7789
#
# Epoch 00053: val_loss did not improve from 0.65023
# Epoch 54/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6362 - accuracy: 0.7905 - val_loss: 0.6556 - val_accuracy: 0.7874
#
# Epoch 00054: val_loss did not improve from 0.65023
# Epoch 55/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6386 - accuracy: 0.7875 - val_loss: 0.6603 - val_accuracy: 0.7835
#
# Epoch 00055: val_loss did not improve from 0.65023
# Epoch 56/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6192 - accuracy: 0.7967 - val_loss: 0.6731 - val_accuracy: 0.7759
#
# Epoch 00056: val_loss did not improve from 0.65023
# Epoch 57/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6182 - accuracy: 0.7941 - val_loss: 0.6870 - val_accuracy: 0.7824
#
# Epoch 00057: val_loss did not improve from 0.65023
# Epoch 58/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6248 - accuracy: 0.7896 - val_loss: 0.6452 - val_accuracy: 0.7888
#
# Epoch 00058: val_loss improved from 0.65023 to 0.64524, saving model to model/cifar10-cnn-58-0.6452.hdf5
# Epoch 59/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6185 - accuracy: 0.7948 - val_loss: 0.6709 - val_accuracy: 0.7777
#
# Epoch 00059: val_loss did not improve from 0.64524
# Epoch 60/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6322 - accuracy: 0.7914 - val_loss: 0.6634 - val_accuracy: 0.7876
#
# Epoch 00060: val_loss did not improve from 0.64524
# Epoch 61/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6133 - accuracy: 0.7949 - val_loss: 0.6858 - val_accuracy: 0.7770
#
# Epoch 00061: val_loss did not improve from 0.64524
# Epoch 62/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6078 - accuracy: 0.7975 - val_loss: 0.6540 - val_accuracy: 0.7846
#
# Epoch 00062: val_loss did not improve from 0.64524
# Epoch 63/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6184 - accuracy: 0.7922 - val_loss: 0.7083 - val_accuracy: 0.7778
#
# Epoch 00063: val_loss did not improve from 0.64524
# Epoch 64/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6075 - accuracy: 0.7959 - val_loss: 0.6437 - val_accuracy: 0.7866
#
# Epoch 00064: val_loss improved from 0.64524 to 0.64374, saving model to model/cifar10-cnn-64-0.6437.hdf5
# Epoch 65/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6126 - accuracy: 0.7960 - val_loss: 0.6425 - val_accuracy: 0.7895
#
# Epoch 00065: val_loss improved from 0.64374 to 0.64253, saving model to model/cifar10-cnn-65-0.6425.hdf5
# Epoch 66/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6100 - accuracy: 0.7972 - val_loss: 0.6583 - val_accuracy: 0.7827
#
# Epoch 00066: val_loss did not improve from 0.64253
# Epoch 67/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6041 - accuracy: 0.8008 - val_loss: 0.6453 - val_accuracy: 0.7908
#
# Epoch 00067: val_loss did not improve from 0.64253
# Epoch 68/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6093 - accuracy: 0.7964 - val_loss: 0.6760 - val_accuracy: 0.7895
#
# Epoch 00068: val_loss did not improve from 0.64253
# Epoch 69/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6147 - accuracy: 0.7965 - val_loss: 0.6523 - val_accuracy: 0.7863
#
# Epoch 00069: val_loss did not improve from 0.64253
# Epoch 70/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6041 - accuracy: 0.8001 - val_loss: 0.6807 - val_accuracy: 0.7872
#
# Epoch 00070: val_loss did not improve from 0.64253
# Epoch 71/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6050 - accuracy: 0.7986 - val_loss: 0.6638 - val_accuracy: 0.7813
#
# Epoch 00071: val_loss did not improve from 0.64253
# Epoch 72/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6058 - accuracy: 0.8006 - val_loss: 0.6787 - val_accuracy: 0.7842
#
# Epoch 00072: val_loss did not improve from 0.64253
# Epoch 73/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6021 - accuracy: 0.8015 - val_loss: 0.6448 - val_accuracy: 0.7883
#
# Epoch 00073: val_loss did not improve from 0.64253
# Epoch 74/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.5978 - accuracy: 0.8039 - val_loss: 0.6709 - val_accuracy: 0.7860
#
# Epoch 00074: val_loss did not improve from 0.64253
# Epoch 75/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6000 - accuracy: 0.7968 - val_loss: 0.7248 - val_accuracy: 0.7783
#
# Epoch 00075: val_loss did not improve from 0.64253

# %%
from tensorflow.keras.models import load_model
model = load_model('model/cifar10-cnn-50-0.6460.hdf5')

# %%
# 테스트 정확도 출력 
acc = model.evaluate(x_test, y_test, verbose=2)[1]
print(f"Test Accuracy: {acc:.4f}")
# Out:
# 313/313 - 1s - loss: 0.6556 - accuracy: 0.7821
# Test Accuracy: 0.7821

# %%
# 검증셋의 오차
y_vloss = history.history['val_loss']

# 학습셋의 오차
y_loss = history.history['loss']

# 그래프로 표현
import matplotlib.pyplot as plt
# %matplotlib inline
x_len = np.arange(1, len(y_loss)+1)
plt.figure(figsize=(8,6))
plt.plot(x_len, y_vloss, marker='.', c="red", label='Validationset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

# 그래프에 그리드를 주고 레이블을 표시
plt.legend(loc='upper right')
#plt.axis([0, 20, 0, 0.35])
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
